# %% [markdown]
# <a href="https://colab.research.google.com/github/NikkiShah93/R/blob/main/C%3A%5CUsers%5C12145%5CDocuments%5CGitHub%5CPython%5CMLProjects%5CPyTorchProjects%5CDeepLearning%5CDeepLearningFundamentals.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Deep Learning Fundamentals with PyTorch

# %%
## first the imports
import numpy as np
import matplotlib.pyplot as plt
import torch
import torchvision

# %%
device = ('cuda' if torch.cuda.is_available() else 'cpu')
torch.manual_seed(1234)
torch.cuda.manual_seed(1234)

## creating a random image tensor
image_tensor = torch.rand((224, 224, 3)) ## height, width, and color channel (R, G, B)
plt.imshow(image_tensor.squeeze())

# %%
rand = torch.arange(0, 10, 2)
print(rand.size())
print(rand.shape)
print(rand.ndim)
print(rand.dtype)
print(rand.requires_grad)
print(rand.device)
# Out:
# torch.Size([5])
# torch.Size([5])
# 1
# torch.int64
# False
# cpu
